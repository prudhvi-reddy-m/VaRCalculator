# %% [markdown]
# # **VaR Calculator - Execution**
#
# #### Author: Prudhvi Reddy, Muppala
# #### Financial Engineer
# #### Date created: 8 Oct 2023
# #### Last updated on: 8 Oct 2023

# %%
# !pip install nbimporter

import nbimporter
from VaRcalculator import VaR
# Out:
# Requirement already satisfied: nbimporter in /Users/prudhvireddymuppala/anaconda3/lib/python3.10/site-packages (0.3.4)

# %%
tickers = ["SPY", "BND", "GLD", "QQQ", "VTI"]

df = VaR(
    ticker=tickers, 
    start_date='2008-10-10', 
    end_date='2023-10-6', 
    rolling_window=5, 
    confidence_level=0.95, 
    portfolio_val=1000000, 
    simulations=100000)
# Out:
# [*********************100%***********************]  5 of 5 completed
